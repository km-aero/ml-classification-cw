# %% [markdown]
# # Read Data
# * Load data
# * Make variables (ind and dep)
# * Describe (statistics of) data
# * save data

# %%
import numpy as np # linear algebra
import pandas as pd # data processing
import pickle # data storage
import os
# more than one output per cell
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
# Allows more columns to be shown for outputs
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 20000)

# %% [markdown]
# ### Set Directory

# %%
dirRawData = "C:/Users/kevin/Google Drive/AML/Projects/Coursework/RawData/"
dirPData = "C:/Users/kevin/Google Drive/AML/Projects/Coursework/PData/"

df_test = pd.read_csv(dirRawData + 'test.csv',
                     na_values = 'NA')
df_train = pd.read_csv(dirRawData + 'train.csv',
                      na_values = 'NA')

# %% [markdown]
# ### shows first 5 rows

# %%
df_train.head()
df_test.head()
# Out:
#    id v_char_1 v_char_2 v_char_3 v_char_4 v_char_5 v_char_6 v_char_7 v_char_8  \
# 0   1        G        V        q        S        Q        K        Q        d
# 1   2        G        I        q        S        Q        i        Q        d
# 2   3        G        I        L        S        Q        L        Q        h
# 3   4        G        I        q        S        Q        i        Q        h
# 4   6        G        V        q        S        Q        i        Q        d
#
#   v_char_9 v_char_10 v_char_11 v_char_12 v_char_13 v_char_14 v_char_15  \
# 0        Y         V         T         n         u         h         C
# 1        I         p         B         v         u         h         C
# 2        I         p         T         M         u         h         C
# 3        I         p         T         M         u         h         C
# 4        Y         V         B         v         u         h         C
#
#   v_char_16 v_char_17 v_char_18 v_char_19 v_char_20 v_char_21 v_char_22  \
# 0         K         N         o         I         Q         S         F
# 1         K         N         f         I         g         S         F
# 2         q         N         f         I         g         w         g
# 3         K         N         f         I         g         S         g
# 4         K         N         a         I         g         S         g
#
#   v_char_23 v_char_24 v_char_25 v_char_26 v_char_27 v_char_28 v_char_29  \
# 0         U         x         r         V         j         U         G
# 1         U         x         r         S         j         N         G
# 2         U         q         r         V         H         N         G
# 3         U         q         r         V         j         N         G
# 4         U         x         r         X         j         U         G
#
#   v_char_30 v_char_31 v_char_32 v_char_33 v_char_34 v_char_35 v_char_36  \
# 0         e         t         D         p         n         X         Q
# 1         e         t         v         p         f         X         o
# 2         e         t         v         p         f         X         Q
# 3         e         t         v         p         f         X         Q
# 4         e         t         v         p         I         X         o
#
#   v_char_37 v_char_38 v_char_39 v_char_40 v_char_41 v_char_42 v_char_43  \
# 0         U         d         Q         W         p         q         p
# 1         U         H         Q         W         j         j         T
# 2         U         H         e         W         p         j         E
# 3         U         H         Q         W         p         j         p
# 4         U         d         Q         W         p         q         f
#
#   v_char_44 v_char_45 v_char_46 v_char_47 v_char_48 v_char_49 v_char_50  \
# 0         k         R         e         A         O         s         F
# 1         N         J         H         j         p         s         F
# 2         C         R         H         j         p         s         F
# 3         C         R         H         A         p         s         F
# 4         N         R         e         j         O         s         F
#
#   v_char_51 v_char_52 v_char_53 v_char_54 v_char_55 v_char_56 v_char_57  \
# 0         b         E         h         b         a         I         N
# 1         b         E         B         i         a         I         N
# 2         b         E         B         i         a         Y         S
# 3         b         E         B         i         a         Y         N
# 4         b         E         L         b         a         Y         N
#
#   v_char_58 v_char_59 v_char_60 v_char_61 v_char_62 v_char_63 v_char_64  \
# 0         P         E         E         u         D         y         P
# 1         S         o         E         O         B         m         U
# 2         P         o         E         a         i         m         U
# 3         P         o         E         u         e         s         U
# 4         P         E         E         K         s         m         o
#
#   v_char_65 v_char_66 v_char_67 v_char_68 v_char_69 v_char_70 v_char_71  \
# 0         R         B         d         m         e         h         p
# 1         R         O         d         X         Q         F         p
# 2         b         C         J         X         Q         F         p
# 3         R         O         d         X         e         h         p
# 4         R         C         d         m         Q         M         p
#
#   v_char_72 v_char_73 v_char_74 v_char_75 v_char_76 v_char_77 v_char_78  \
# 0         o         w         S         q         l         K         b
# 1         T         c         n         p         l         K         s
# 2         T         F         n         p         l         P         s
# 3         T         w         n         p         l         K         s
# 4         o         w         S         q         l         K         h
#
#   v_char_79 v_char_80 v_char_81 v_char_82 v_char_83 v_char_84 v_char_85  \
# 0         G         w         D         c         h         Y         E
# 1         C         l         D         c         h         q         E
# 2         C         l         D         c         h         q         X
# 3         C         l         D         c         h         o         E
# 4         G         B         D         c         h         q         E
#
#   v_char_86 v_char_87 v_char_88 v_char_89 v_char_90 v_char_91 v_char_92  \
# 0         f         E         L         l         d         M         f
# 1         f         E         L         i         H         M         Q
# 2         i         E         L         i         H         M         Q
# 3         f         E         L         i         H         M         Q
# 4         f         E         L         l         d         M         f
#
#   v_char_93 v_char_94 v_char_95 v_char_96 v_char_97 v_char_98 v_char_99  \
# 0         a         R         M         u         a         E         f
# 1         a         E         M         u         a         E         f
# 2         M         E         M         q         a         E         Y
# 3         a         E         M         u         a         E         f
# 4         a         R         M         u         a         E         f
#
#   v_char_100 v_char_101 v_char_102 v_char_103 v_char_104 v_char_105  \
# 0          q          T          F          a          t          h
# 1          q          v          F          a          t          i
# 2          q          T          F          I          t          h
# 3          q          T          F          z          t          h
# 4          Q          T          F          a          S          h
#
#   v_char_106 v_char_107 v_char_108 v_char_109 v_char_110 v_char_111  \
# 0          Q          Z          P          C          q          e
# 1          H          Z          P          s          q          q
# 2          H          F          P          s          q          q
# 3          H          Z          P          s          q          q
# 4          Q          Z          P          C          q          e
#
#   v_char_112 v_char_113 v_char_114 v_char_115 v_char_116 v_char_117  \
# 0          M          h          D          p          n          s
# 1          f          h          D          F          n          s
# 2          f          B          D          F          n          s
# 3          f          h          D          F          n          s
# 4          M          h          D          p          n          s
#
#   v_char_118 v_char_119 v_char_120 v_char_121 v_char_122 v_char_123  v_num_1  \
# 0          a          z          q          j          W          n        0
# 1          d          z          q          j          W          n        0
# 2          d          z          q          j          W          n        0
# 3          d          z          q          j          W          n        0
# 4          P          z          q          j          W          n        0
#
#    v_num_2  v_num_3  v_num_4  v_num_5  v_num_6  v_num_7  v_num_8  v_num_9  \
# 0        0        8        1       14        0        7        0        1
# 1       19        5        0        1        0        1        0        1
# 2        0        8        0        3        0        7        1        1
# 3        0        6        0        5        0        7        0        1
# 4        0        6        0        4        0        7        0        1
#
#    v_num_10  v_num_11  v_num_12  v_num_13  v_num_14  v_num_15  v_num_16  \
# 0         6         1         0         0         1         3         9
# 1        11        -2         0         0        -2        -2         1
# 2         3        -2         0         0        -2        -2        10
# 3         8        -2         0         0        -2        -2         3
# 4         8         1         0         0         4         3         6
#
#    v_num_17  v_num_18  v_num_19  v_num_20  v_num_21  v_num_22  v_num_23  \
# 0         1         3         0        11         2         0         3
# 1         1         0         0         2        10         0        15
# 2         1        10         0         5         3         0         3
# 3         1         7         0         8         4         0         7
# 4         1        11         0         5         6         0         2
#
#    v_num_24  v_num_25  v_num_26  v_num_27  v_num_28  v_num_29  v_num_30  \
# 0        -1         1         0         3        18         1         1
# 1        -2         1         0        -1        15        -2         1
# 2        -2         1         0        -1        12        -2         1
# 3        -2         1         0        -1        19        -2         1
# 4        14         1         2         1        16         1         1
#
#    v_num_31  target  v_num_33  v_num_34  v_num_35  v_num_36  v_num_37  \
# 0         7       0         2         0         1        20         0
# 1         5       0         1         0         4         3         6
# 2        10       0         1         0         2        10         0
# 3        17       1         1         1         1        16         0
# 4        16       0         1         0         1        19         0
#
#    v_num_38  v_num_39  v_num_40  v_num_41  v_num_42  v_num_43  v_num_44  \
# 0        10        10         0         0         7         0        11
# 1         5        19         0         0         3        10         5
# 2         2         4         0         0        10         0         7
# 3        15         7         0         0         6         0         2
# 4         1         4         0         0        13         0         2
#
#    v_num_45  v_num_46  v_num_47  v_num_48  v_num_49  v_num_50  v_num_51  \
# 0         0         0         0         0         0         4        13
# 1         0         0         0         0         8         0        -2
# 2         0         0         0         0         0         4        -2
# 3         0         0         0         0         0         4        -2
# 4         0         0         0         0         0         3         9
#
#    v_num_52  v_num_53  v_num_54  v_num_55  v_num_56  v_num_57  v_num_58  \
# 0         3         7        12         7         1         1         0
# 1         8         3         1         3         1        12         0
# 2         1        10         6         3         1         7         0
# 3         5         6        10         3         1        10         1
# 4         5        12        11         3         1        10         0
#
#    v_num_59  v_num_60  v_num_61  v_num_62  v_num_63  v_num_64  v_num_65  \
# 0         3         3         7        12         0         1         0
# 1         1        -2         2         2         3        -2        13
# 2         3        -2         5        11         1        -2         9
# 3         3        -2         4         5         1        -2        11
# 4         5         0         5         8         1         1        11
#
#    v_num_66  v_num_67  v_num_68  v_num_69  v_num_70  v_num_71  v_num_72  \
# 0        -1         1        11        12         7         1         2
# 1        20         1        -2         1         1         1         2
# 2        -1         1        -2         7         3         1         2
# 3        -1         1        -2        11         6         1         2
# 4        -1         1         5        12         1         1         2
#
#    v_num_73  v_num_74  v_num_75  v_num_76  v_num_77  v_num_78  v_num_79  \
# 0         0         1         5         1         1         0         9
# 1         0         1        18         1         0         1         3
# 2         0         1         4         1         4         0         3
# 3         0         1         1         1         4         0         9
# 4         0         1         1         1         0         0         1
#
#    v_num_80  v_num_81  v_num_82  v_num_84  v_num_85  v_num_86  v_num_87  \
# 0        17        20         1         0         0        16         0
# 1        -2         2         1         0         0         8         0
# 2        -2        11         1         0         1        15         0
# 3        -2        17         1         0         0        16         0
# 4         8        17         1         0         0         6         0
#
#    v_num_88  v_num_89  v_num_90  v_num_91  v_num_92  v_num_94  v_num_95  \
# 0         8         2         1         0        10         0         0
# 1         5         2         1         0         4         0         0
# 2         7         1         1         0        13         0         0
# 3         1         3         1         0        18         0         0
# 4         1         3         2         0        17         0         0
#
#    v_num_96  v_num_97  v_num_98  v_num_99  v_num_100  v_num_101  v_num_102  \
# 0         0         7        10         0          1          0          6
# 1         0        16         2         0          1          0          7
# 2         0         7         3         0          1          0          6
# 3         0        11        10         0          1          0          6
# 4         0         4         1         0          1          0         11
#
#    v_num_103  v_num_104  v_num_105  v_num_106  v_num_107  v_num_108  \
# 0          0          6          8          0          1          0
# 1          1          5          1          5          1          1
# 2          0          8          9          0          1          0
# 3          0          8          1          0          1          0
# 4          0          5          3          0          1          0
#
#    v_num_109  v_num_110
# 0         16         19
# 1          7          2
# 2          1          4
# 3         12          8
# 4         16          4
#    id v_char_1 v_char_2 v_char_3 v_char_4 v_char_5 v_char_6 v_char_7 v_char_8  \
# 0   5        G        I        L        S        Q        L        Q        h
# 1  10        G        Q        q        S        Q        i        V        h
# 2  11        G        O        q        S        Q        i        Q        h
# 3  13        G        I        q        S        Q        i        Q        d
# 4  16        G        V        q        S        Q        K        Q        h
#
#   v_char_9 v_char_10 v_char_11 v_char_12 v_char_13 v_char_14 v_char_15  \
# 0        I         p         T         D         u         h         C
# 1        A         V         T         M         u         t         C
# 2        Y         V         T         v         u         t         C
# 3        I         p         T         v         u         t         C
# 4        Y         V         T         n         u         h         C
#
#   v_char_16 v_char_17 v_char_18 v_char_19 v_char_20 v_char_21 v_char_22  \
# 0         K         N         f         I         Q         w         F
# 1         K         N         o         I         g         S         g
# 2         K         N         a         I         Q         S         g
# 3         K         N         f         I         g         S         F
# 4         K         N         a         I         Q         S         F
#
#   v_char_23 v_char_24 v_char_25 v_char_26 v_char_27 v_char_28 v_char_29  \
# 0         U         q         r         V         H         N         E
# 1         U         q         r         V         j         U         G
# 2         U         q         r         V         H         U         G
# 3         U         x         r         V         j         N         G
# 4         U         q         r         V         j         U         G
#
#   v_char_30 v_char_31 v_char_32 v_char_33 v_char_34 v_char_35 v_char_36  \
# 0         e         t         D         p         f         X         Q
# 1         e         t         v         p         I         X         Q
# 2         e         t         D         p         C         X         o
# 3         e         t         v         p         f         X         o
# 4         e         t         D         p         I         X         Q
#
#   v_char_37 v_char_38 v_char_39 v_char_40 v_char_41 v_char_42 v_char_43  \
# 0         U         H         e         W         j         j         p
# 1         U         d         Q         W         j         q         D
# 2         U         d         Q         W         p         q         D
# 3         U         H         Q         W         p         j         p
# 4         U         d         Q         W         j         q         e
#
#   v_char_44 v_char_45 v_char_46 v_char_47 v_char_48 v_char_49 v_char_50  \
# 0         k         b         H         A         p         t         F
# 1         C         J         e         A         O         s         F
# 2         N         R         e         j         h         s         F
# 3         N         R         H         A         p         s         F
# 4         k         p         O         j         O         s         F
#
#   v_char_51 v_char_52 v_char_53 v_char_54 v_char_55 v_char_56 v_char_57  \
# 0         b         Y         B         i         a         Y         N
# 1         b         E         h         b         a         Y         N
# 2         b         E         L         M         a         Y         N
# 3         b         E         B         i         a         Y         N
# 4         b         E         L         b         a         I         N
#
#   v_char_58 v_char_59 v_char_60 v_char_61 v_char_62 v_char_63 v_char_64  \
# 0         P         o         E         K         D         m         U
# 1         S         E         E         p         D         m         P
# 2         P         E         E         u         D         g         P
# 3         P         o         E         c         s         m         U
# 4         P         E         E         O         D         s         P
#
#   v_char_65 v_char_66 v_char_67 v_char_68 v_char_69 v_char_70 v_char_71  \
# 0         b         C         d         X         Q         h         p
# 1         z         C         d         M         Q         h         p
# 2         R         x         d         m         e         F         p
# 3         R         C         d         X         Q         o         p
# 4         z         O         d         m         Q         F         p
#
#   v_char_72 v_char_73 v_char_74 v_char_75 v_char_76 v_char_77 v_char_78  \
# 0         T         F         n         p         P         P         s
# 1         o         w         S         q         l         K         h
# 2         o         w         S         q         l         K         h
# 3         T         w         n         p         l         K         s
# 4         o         w         S         q         l         K         h
#
#   v_char_79 v_char_80 v_char_81 v_char_82 v_char_83 v_char_84 v_char_85  \
# 0         C         l         D         c         h         q         E
# 1         G         w         D         c         h         q         E
# 2         G         B         D         c         h         I         E
# 3         C         l         D         c         h         q         E
# 4         G         B         D         c         h         o         E
#
#   v_char_86 v_char_87 v_char_88 v_char_89 v_char_90 v_char_91 v_char_92  \
# 0         i         E         L         i         H         M         Q
# 1         f         E         L         j         d         Z         f
# 2         f         E         L         l         d         M         f
# 3         f         E         L         i         H         M         Q
# 4         f         E         L         l         d         M         f
#
#   v_char_93 v_char_94 v_char_95 v_char_96 v_char_97 v_char_98 v_char_99  \
# 0         a         E         M         q         T         V         Y
# 1         a         R         M         u         a         E         f
# 2         a         R         M         j         a         E         f
# 3         a         E         M         u         a         E         D
# 4         a         R         M         u         a         E         f
#
#   v_char_100 v_char_101 v_char_102 v_char_103 v_char_104 v_char_105  \
# 0          q          F          F          z          t          i
# 1          q          v          F          a          t          h
# 2          Q          T          F          I          t          h
# 3          q          T          F          a          t          h
# 4          q          F          F          I          t          h
#
#   v_char_106 v_char_107 v_char_108 v_char_109 v_char_110 v_char_111  \
# 0          H          F          P          s          y          q
# 1          Q          Z          P          C          q          e
# 2          Q          Z          P          C          q          e
# 3          H          Z          P          s          q          q
# 4          Q          Z          P          C          q          e
#
#   v_char_112 v_char_113 v_char_114 v_char_115 v_char_116 v_char_117  \
# 0          f          d          D          F          n          s
# 1          M          h          D          p          n          s
# 2          M          h          D          p          n          s
# 3          f          h          D          F          n          s
# 4          M          h          D          p          n          s
#
#   v_char_118 v_char_119 v_char_120 v_char_121 v_char_122 v_char_123  v_num_1  \
# 0          d          z          q          j          W          n        0
# 1          P          z          q          j          W          n        5
# 2          P          z          q          j          W          n        0
# 3          d          z          q          j          W          n        0
# 4          P          z          q          j          W          n        0
#
#    v_num_2  v_num_3  v_num_4  v_num_5  v_num_6  v_num_7  v_num_8  v_num_9  \
# 0       18        6        0        1        0       12        0        1
# 1        2        5        0        1        1        2        1        1
# 2        0        7        1       12        0        7        1        1
# 3        0        5        0        0        0        7        0        1
# 4        1        5        0        9        0        3        1        1
#
#    v_num_10  v_num_11  v_num_12  v_num_13  v_num_14  v_num_15  v_num_16  \
# 0         5        -2         0         0        -2        -2         1
# 1         8         1         0         0         7         8         8
# 2         5         1         0         0         2         6         1
# 3         1        -2         0         0        -2        -2         6
# 4         9         1         0         0         8         5         1
#
#    v_num_17  v_num_18  v_num_19  v_num_20  v_num_21  v_num_22  v_num_23  \
# 0         1         0         0         3        11         0        10
# 1         1        11         1         4         0         0        16
# 2         1        13         0        14        11         0         4
# 3         1         0         0         7         4         0         1
# 4         1         0         0         8         1         0        14
#
#    v_num_24  v_num_25  v_num_26  v_num_27  v_num_28  v_num_29  v_num_30  \
# 0        -2         2         0        -1         7        -2         1
# 1        -1         1         2         1        17         1         1
# 2         3         1         0         2        19         1         1
# 3        -2         1         0        -1        17        -2         1
# 4        10         1         1         1        13         1         1
#
#    v_num_31  v_num_33  v_num_34  v_num_35  v_num_36  v_num_37  v_num_38  \
# 0         2         1         1         2         7         0        13
# 1         9         1         0         1        19        16         6
# 2        17         4         2         6         9         0         6
# 3        11         1         0         3        14         0        13
# 4         5         1         0         2        20         0         3
#
#    v_num_39  v_num_40  v_num_41  v_num_42  v_num_43  v_num_44  v_num_45  \
# 0         3         0         0         4        19         1         0
# 1         5         0         0         8         1         1         0
# 2        15         0         0         9         0         8        -1
# 3         6         0         0         5         0         2         0
# 4         6         0         0         3         1         1         0
#
#    v_num_46  v_num_47  v_num_48  v_num_49  v_num_50  v_num_51  v_num_52  \
# 0         0         1         0         0         3        -2         7
# 1         0         0         0         0         1        10        11
# 2         0         0         0         0         4        18         2
# 3         0         0         0         7         0        -2         1
# 4         0         1         0         6         1        17        13
#
#    v_num_53  v_num_54  v_num_55  v_num_56  v_num_57  v_num_58  v_num_59  \
# 0         4         6         3         1         7         0         3
# 1         2         5         0         1         9         0         5
# 2         9         6         3         1        10         0         3
# 3         5         8         3         1         9         0         3
# 4         3         4         6         1         3         0         1
#
#    v_num_60  v_num_61  v_num_62  v_num_63  v_num_64  v_num_65  v_num_66  \
# 0        -2         5        19         1        -2         1        15
# 1         8         5         4         5         1        17         7
# 2        -2         5         4         1         1         9        -1
# 3        -2         1         6         4        -2        13        -1
# 4         6         5        13         1         2         3         4
#
#    v_num_67  v_num_68  v_num_69  v_num_70  v_num_71  v_num_72  v_num_73  \
# 0         1        -2         7         0         1         2         0
# 1         1         5        12         1         1         2         0
# 2         1        14         8         1         1         2         0
# 3         1        -2         9         0         1         2         0
# 4         1         7        10         5         1         2         0
#
#    v_num_74  v_num_75  v_num_76  v_num_77  v_num_78  v_num_79  v_num_80  \
# 0         1        15         1         0         0         5        -2
# 1         1        20         1         6         0         2         2
# 2         1         1         1         0         0        19        15
# 3         1        -1         1         7         0         2        -2
# 4         1        16         1         4         0        18        15
#
#    v_num_81  v_num_82  v_num_84  v_num_85  v_num_86  v_num_87  v_num_88  \
# 0         3         1         0         0         1         0         5
# 1         9         1         0         0         9         0         1
# 2        13         1         0         0         4         0         3
# 3         5         1         0         0        11         0         6
# 4         9         1         0         1        12         0         1
#
#    v_num_89  v_num_90  v_num_91  v_num_92  v_num_94  v_num_95  v_num_96  \
# 0         1         1         0         3         0         0         4
# 1         2         2         0         1         0         0         6
# 2         2         1         0        18         2         0         0
# 3         3         1         0        13         0         0         0
# 4         2         1         0         8         0         0         9
#
#    v_num_97  v_num_98  v_num_99  v_num_100  v_num_101  v_num_102  v_num_103  \
# 0         3         2         0          1          0          6          0
# 1        11         2         0          1          0          4          1
# 2         9        19         0          1          0          6          0
# 3         1         2         0          1          0          8          0
# 4        15        18         0          1          0          6          0
#
#    v_num_104  v_num_105  v_num_106  v_num_107  v_num_108  v_num_109  v_num_110
# 0          7          1          0          1          0          2         14
# 1          1          4          0          1          1         10          1
# 2          2          1          0          1          0         18         12
# 3          1          5          0          1          0          1          2
# 4         12          1          0          1          0         18         18

# %% [markdown]
# ### Store data with pickle

# %%
dict_ = {'df_test': df_test,
        'df_train': df_train}

f_name = dirPData + 'Vars.pickle'
with open(f_name, "wb") as f:
    pickle.dump(dict_,f)
del f_name
